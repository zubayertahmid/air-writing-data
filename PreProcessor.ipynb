# %%
import os
import pandas as pd
from scipy.stats import zscore

# === Preprocessing Functions ===

def leaky_integrator(signal, lambda_=0.9):
    smoothed = [signal.iloc[0]]
    for i in range(1, len(signal)):
        smoothed.append(lambda_ * smoothed[i - 1] + (1 - lambda_) * signal.iloc[i])
    return smoothed

def preprocess(df: pd.DataFrame) -> pd.DataFrame:
    # Keep only the relevant accelerometer columns
    acc = df[["acc_x", "acc_y", "acc_z"]].copy()

    # Apply leaky integrator smoothing
    acc["x_smooth"] = leaky_integrator(acc["acc_x"])
    acc["y_smooth"] = leaky_integrator(acc["acc_y"])
    acc["z_smooth"] = leaky_integrator(acc["acc_z"])

    # Apply z-score normalization
    acc["x_norm"] = zscore(acc["x_smooth"])
    acc["y_norm"] = zscore(acc["y_smooth"])
    acc["z_norm"] = zscore(acc["z_smooth"])

    # Return only normalized columns
    return acc[["x_norm", "y_norm", "z_norm"]]

# === Folder Setup ===

BASE_DIR = "recordings"
OUTPUT_DIR = os.path.join(BASE_DIR, "preprocessed_data")

# Make sure output directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

# === Iterate Over Character Folders and CSV Files ===

for char_folder in os.listdir(BASE_DIR):
    char_path = os.path.join(BASE_DIR, char_folder)

    # Skip non-folders and the output folder itself
    if not os.path.isdir(char_path) or char_folder == "preprocessed_data":
        continue

    # Create output subfolder for the character
    output_char_folder = os.path.join(OUTPUT_DIR, char_folder)
    os.makedirs(output_char_folder, exist_ok=True)

    for csv_file in os.listdir(char_path):
        if not csv_file.endswith(".csv"):
            continue

        input_path = os.path.join(char_path, csv_file)

        try:
            df = pd.read_csv(input_path)
            processed_df = preprocess(df)

            # Prepare new filename
            file_root, ext = os.path.splitext(csv_file)
            new_filename = f"{file_root}_preprocessed{ext}"
            output_path = os.path.join(output_char_folder, new_filename)

            # Save processed file
            processed_df.to_csv(output_path, index=False)
            print(f"[✓] Processed: {input_path} -> {output_path}")

        except Exception as e:
            print(f"[✗] Failed to process {input_path}: {e}")
# Out:
# [✓] Processed: recordings\অ\অ_36606b04_Right Hand_20250423_120617.csv -> recordings\preprocessed_data\অ\অ_36606b04_Right Hand_20250423_120617_preprocessed.csv
# [✓] Processed: recordings\অ\অ_36606b04_Right Hand_20250423_120731.csv -> recordings\preprocessed_data\অ\অ_36606b04_Right Hand_20250423_120731_preprocessed.csv
# [✓] Processed: recordings\আ\আ_36606b04_Right Hand_20250423_120748.csv -> recordings\preprocessed_data\আ\আ_36606b04_Right Hand_20250423_120748_preprocessed.csv
# [✓] Processed: recordings\আ\আ_36606b04_Right Hand_20250423_120805.csv -> recordings\preprocessed_data\আ\আ_36606b04_Right Hand_20250423_120805_preprocessed.csv
# [✓] Processed: recordings\ক\ক_01083526_Right Hand_20250423_122648.csv -> recordings\preprocessed_data\ক\ক_01083526_Right Hand_20250423_122648_preprocessed.csv
# [✓] Processed: recordings\ক\ক_01083526_Right Hand_20250423_122659.csv -> recordings\preprocessed_data\ক\ক_01083526_Right Hand_20250423_122659_preprocessed.csv
# [✓] Processed: recordings\ক\ক_01083526_Right Hand_20250423_122711.csv -> recordings\preprocessed_data\ক\ক_01083526_Right Hand_20250423_122711_preprocessed.csv
# [✓] Processed: recordings\ক\ক_117fb6fc_Right Hand_20250423_122340.csv -> recordings\preprocessed_data\ক\ক_117fb6fc_Right Hand_20250423_122340_preprocessed.csv
# [✓] Processed: recordings\ক\ক_117fb6fc_Right Hand_20250423_122352.csv -> recordings\preprocessed_data\ক\ক_117fb6fc_Right Hand_20250423_122352_preprocessed.csv
# [✓] Processed: recordings\ক\ক_36606b04_Right Hand_20250423_120831.csv -> recordings\preprocessed_data\ক\ক_36606b04_Right Hand_20250423_120831_preprocessed.csv
# [✓] Processed: recordings\ক\ক_36606b04_Right Hand_20250423_120849.csv -> recordings\preprocessed_data\ক\ক_36606b04_Right Hand_20250423_120849_preprocessed.csv
# [✓] Processed: recordings\ক\ক_36bd5490_Right Hand_20250423_122018.csv -> recordings\preprocessed_data\ক\ক_36bd5490_Right Hand_20250423_122018_preprocessed.csv
# [✓] Processed: recordings\ক\ক_36bd5490_Right Hand_20250423_122033.csv -> recordings\preprocessed_data\ক\ক_36bd5490_Right Hand_20250423_122033_preprocessed.csv
# [✓] Processed: recordings\ক\ক_95d236ec_Right Hand_20250423_123211.csv -> recordings\preprocessed_data\ক\ক_95d236ec_Right Hand_20250423_123211_preprocessed.csv
# [✓] Processed: recordings\ক\ক_95d236ec_Right Hand_20250423_123222.csv -> recordings\preprocessed_data\ক\ক_95d236ec_Right Hand_20250423_123222_preprocessed.csv
# [✓] Processed: recordings\ক\ক_b16dc8e1_Right Hand_20250423_121342.csv -> recordings\preprocessed_data\ক\ক_b16dc8e1_Right Hand_20250423_121342_preprocessed.csv
# [✓] Processed: recordings\ক\ক_b16dc8e1_Right Hand_20250423_121354.csv -> recordings\preprocessed_data\ক\ক_b16dc8e1_Right Hand_20250423_121354_preprocessed.csv
# [✓] Processed: recordings\ক\ক_f10a33d9_Right Hand_20250423_122941.csv -> recordings\preprocessed_data\ক\ক_f10a33d9_Right Hand_20250423_122941_preprocessed.csv
# [✓] Processed: recordings\ক\ক_f10a33d9_Right Hand_20250423_122953.csv -> recordings\preprocessed_data\ক\ক_f10a33d9_Right Hand_20250423_122953_preprocessed.csv
# [✓] Processed: recordings\খ\খ_01083526_Right Hand_20250423_122739.csv -> recordings\preprocessed_data\খ\খ_01083526_Right Hand_20250423_122739_preprocessed.csv
# [✓] Processed: recordings\খ\খ_01083526_Right Hand_20250423_122752.csv -> recordings\preprocessed_data\খ\খ_01083526_Right Hand_20250423_122752_preprocessed.csv
# [✓] Processed: recordings\খ\খ_117fb6fc_Right Hand_20250423_122409.csv -> recordings\preprocessed_data\খ\খ_117fb6fc_Right Hand_20250423_122409_preprocessed.csv
# [✓] Processed: recordings\খ\খ_117fb6fc_Right Hand_20250423_122435.csv -> recordings\preprocessed_data\খ\খ_117fb6fc_Right Hand_20250423_122435_preprocessed.csv
# [✓] Processed: recordings\খ\খ_36606b04_Right Hand_20250423_120920.csv -> recordings\preprocessed_data\খ\খ_36606b04_Right Hand_20250423_120920_preprocessed.csv
# [✓] Processed: recordings\খ\খ_36606b04_Right Hand_20250423_120938.csv -> recordings\preprocessed_data\খ\খ_36606b04_Right Hand_20250423_120938_preprocessed.csv
# [✓] Processed: recordings\খ\খ_36bd5490_Right Hand_20250423_122053.csv -> recordings\preprocessed_data\খ\খ_36bd5490_Right Hand_20250423_122053_preprocessed.csv
# [✓] Processed: recordings\খ\খ_36bd5490_Right Hand_20250423_122106.csv -> recordings\preprocessed_data\খ\খ_36bd5490_Right Hand_20250423_122106_preprocessed.csv
# [✓] Processed: recordings\খ\খ_36bd5490_Right Hand_20250423_122142.csv -> recordings\preprocessed_data\খ\খ_36bd5490_Right Hand_20250423_122142_preprocessed.csv
# [✓] Processed: recordings\খ\খ_95d236ec_Right Hand_20250423_123238.csv -> recordings\preprocessed_data\খ\খ_95d236ec_Right Hand_20250423_123238_preprocessed.csv
# [✓] Processed: recordings\খ\খ_95d236ec_Right Hand_20250423_123249.csv -> recordings\preprocessed_data\খ\খ_95d236ec_Right Hand_20250423_123249_preprocessed.csv
# [✓] Processed: recordings\খ\খ_b16dc8e1_Right Hand_20250423_121413.csv -> recordings\preprocessed_data\খ\খ_b16dc8e1_Right Hand_20250423_121413_preprocessed.csv
# [✓] Processed: recordings\খ\খ_b16dc8e1_Right Hand_20250423_121427.csv -> recordings\preprocessed_data\খ\খ_b16dc8e1_Right Hand_20250423_121427_preprocessed.csv
# [✓] Processed: recordings\খ\খ_f10a33d9_Right Hand_20250423_123009.csv -> recordings\preprocessed_data\খ\খ_f10a33d9_Right Hand_20250423_123009_preprocessed.csv
# [✓] Processed: recordings\খ\খ_f10a33d9_Right Hand_20250423_123022.csv -> recordings\preprocessed_data\খ\খ_f10a33d9_Right Hand_20250423_123022_preprocessed.csv
# [✓] Processed: recordings\গ\গ_01083526_Right Hand_20250423_122811.csv -> recordings\preprocessed_data\গ\গ_01083526_Right Hand_20250423_122811_preprocessed.csv
# [✓] Processed: recordings\গ\গ_01083526_Right Hand_20250423_122821.csv -> recordings\preprocessed_data\গ\গ_01083526_Right Hand_20250423_122821_preprocessed.csv
# [✓] Processed: recordings\গ\গ_117fb6fc_Right Hand_20250423_122452.csv -> recordings\preprocessed_data\গ\গ_117fb6fc_Right Hand_20250423_122452_preprocessed.csv
# [✓] Processed: recordings\গ\গ_117fb6fc_Right Hand_20250423_122506.csv -> recordings\preprocessed_data\গ\গ_117fb6fc_Right Hand_20250423_122506_preprocessed.csv
# [✓] Processed: recordings\গ\গ_36606b04_Right Hand_20250423_121000.csv -> recordings\preprocessed_data\গ\গ_36606b04_Right Hand_20250423_121000_preprocessed.csv
# [✓] Processed: recordings\গ\গ_36606b04_Right Hand_20250423_121017.csv -> recordings\preprocessed_data\গ\গ_36606b04_Right Hand_20250423_121017_preprocessed.csv
# [✓] Processed: recordings\গ\গ_36606b04_Right Hand_20250423_121036.csv -> recordings\preprocessed_data\গ\গ_36606b04_Right Hand_20250423_121036_preprocessed.csv
# [✓] Processed: recordings\গ\গ_36606b04_Right Hand_20250423_121050.csv -> recordings\preprocessed_data\গ\গ_36606b04_Right Hand_20250423_121050_preprocessed.csv
# [✓] Processed: recordings\গ\গ_36bd5490_Right Hand_20250423_122200.csv -> recordings\preprocessed_data\গ\গ_36bd5490_Right Hand_20250423_122200_preprocessed.csv
# [✓] Processed: recordings\গ\গ_36bd5490_Right Hand_20250423_122213.csv -> recordings\preprocessed_data\গ\গ_36bd5490_Right Hand_20250423_122213_preprocessed.csv
# [✓] Processed: recordings\গ\গ_95d236ec_Right Hand_20250423_123305.csv -> recordings\preprocessed_data\গ\গ_95d236ec_Right Hand_20250423_123305_preprocessed.csv
# [✓] Processed: recordings\গ\গ_95d236ec_Right Hand_20250423_123317.csv -> recordings\preprocessed_data\গ\গ_95d236ec_Right Hand_20250423_123317_preprocessed.csv
# [✓] Processed: recordings\গ\গ_b16dc8e1_Right Hand_20250423_121447.csv -> recordings\preprocessed_data\গ\গ_b16dc8e1_Right Hand_20250423_121447_preprocessed.csv
# [✓] Processed: recordings\গ\গ_b16dc8e1_Right Hand_20250423_121501.csv -> recordings\preprocessed_data\গ\গ_b16dc8e1_Right Hand_20250423_121501_preprocessed.csv
# [✓] Processed: recordings\গ\গ_f10a33d9_Right Hand_20250423_123038.csv -> recordings\preprocessed_data\গ\গ_f10a33d9_Right Hand_20250423_123038_preprocessed.csv
# [✓] Processed: recordings\গ\গ_f10a33d9_Right Hand_20250423_123050.csv -> recordings\preprocessed_data\গ\গ_f10a33d9_Right Hand_20250423_123050_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_01083526_Right Hand_20250423_122836.csv -> recordings\preprocessed_data\ঘ\ঘ_01083526_Right Hand_20250423_122836_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_01083526_Right Hand_20250423_122848.csv -> recordings\preprocessed_data\ঘ\ঘ_01083526_Right Hand_20250423_122848_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_117fb6fc_Right Hand_20250423_122528.csv -> recordings\preprocessed_data\ঘ\ঘ_117fb6fc_Right Hand_20250423_122528_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_117fb6fc_Right Hand_20250423_122540.csv -> recordings\preprocessed_data\ঘ\ঘ_117fb6fc_Right Hand_20250423_122540_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_36606b04_Right Hand_20250423_121111.csv -> recordings\preprocessed_data\ঘ\ঘ_36606b04_Right Hand_20250423_121111_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_36606b04_Right Hand_20250423_121127.csv -> recordings\preprocessed_data\ঘ\ঘ_36606b04_Right Hand_20250423_121127_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_36606b04_Right Hand_20250423_121143.csv -> recordings\preprocessed_data\ঘ\ঘ_36606b04_Right Hand_20250423_121143_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_36bd5490_Right Hand_20250423_122226.csv -> recordings\preprocessed_data\ঘ\ঘ_36bd5490_Right Hand_20250423_122226_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_36bd5490_Right Hand_20250423_122241.csv -> recordings\preprocessed_data\ঘ\ঘ_36bd5490_Right Hand_20250423_122241_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_95d236ec_Right Hand_20250423_123332.csv -> recordings\preprocessed_data\ঘ\ঘ_95d236ec_Right Hand_20250423_123332_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_95d236ec_Right Hand_20250423_123344.csv -> recordings\preprocessed_data\ঘ\ঘ_95d236ec_Right Hand_20250423_123344_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_95d236ec_Right Hand_20250423_123356.csv -> recordings\preprocessed_data\ঘ\ঘ_95d236ec_Right Hand_20250423_123356_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_b16dc8e1_Right Hand_20250423_121522.csv -> recordings\preprocessed_data\ঘ\ঘ_b16dc8e1_Right Hand_20250423_121522_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_b16dc8e1_Right Hand_20250423_121535.csv -> recordings\preprocessed_data\ঘ\ঘ_b16dc8e1_Right Hand_20250423_121535_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_f10a33d9_Right Hand_20250423_123105.csv -> recordings\preprocessed_data\ঘ\ঘ_f10a33d9_Right Hand_20250423_123105_preprocessed.csv
# [✓] Processed: recordings\ঘ\ঘ_f10a33d9_Right Hand_20250423_123116.csv -> recordings\preprocessed_data\ঘ\ঘ_f10a33d9_Right Hand_20250423_123116_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_01083526_Right Hand_20250423_122905.csv -> recordings\preprocessed_data\ঙ\ঙ_01083526_Right Hand_20250423_122905_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_01083526_Right Hand_20250423_122919.csv -> recordings\preprocessed_data\ঙ\ঙ_01083526_Right Hand_20250423_122919_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_117fb6fc_Right Hand_20250423_122559.csv -> recordings\preprocessed_data\ঙ\ঙ_117fb6fc_Right Hand_20250423_122559_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_117fb6fc_Right Hand_20250423_122610.csv -> recordings\preprocessed_data\ঙ\ঙ_117fb6fc_Right Hand_20250423_122610_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_36606b04_Right Hand_20250423_121205.csv -> recordings\preprocessed_data\ঙ\ঙ_36606b04_Right Hand_20250423_121205_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_36606b04_Right Hand_20250423_121222.csv -> recordings\preprocessed_data\ঙ\ঙ_36606b04_Right Hand_20250423_121222_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_36bd5490_Right Hand_20250423_122256.csv -> recordings\preprocessed_data\ঙ\ঙ_36bd5490_Right Hand_20250423_122256_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_36bd5490_Right Hand_20250423_122309.csv -> recordings\preprocessed_data\ঙ\ঙ_36bd5490_Right Hand_20250423_122309_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_95d236ec_Right Hand_20250423_123417.csv -> recordings\preprocessed_data\ঙ\ঙ_95d236ec_Right Hand_20250423_123417_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_95d236ec_Right Hand_20250423_123428.csv -> recordings\preprocessed_data\ঙ\ঙ_95d236ec_Right Hand_20250423_123428_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_b16dc8e1_Right Hand_20250423_121551.csv -> recordings\preprocessed_data\ঙ\ঙ_b16dc8e1_Right Hand_20250423_121551_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_b16dc8e1_Right Hand_20250423_121605.csv -> recordings\preprocessed_data\ঙ\ঙ_b16dc8e1_Right Hand_20250423_121605_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_f10a33d9_Right Hand_20250423_123132.csv -> recordings\preprocessed_data\ঙ\ঙ_f10a33d9_Right Hand_20250423_123132_preprocessed.csv
# [✓] Processed: recordings\ঙ\ঙ_f10a33d9_Right Hand_20250423_123142.csv -> recordings\preprocessed_data\ঙ\ঙ_f10a33d9_Right Hand_20250423_123142_preprocessed.csv
