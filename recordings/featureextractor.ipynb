# %%
import os
import numpy as np
import pandas as pd
from scipy import stats
from scipy.signal import find_peaks
from scipy.fft import fft
import warnings
from pathlib import Path
warnings.filterwarnings('ignore')

# Function to create directory if it doesn't exist
def create_dir_if_not_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Created directory: {directory}")

# Time-domain features
def extract_time_domain_features(data):
    features = {}
    
    # Extract features for each axis
    for axis in ['x_norm', 'y_norm', 'z_norm']:
        axis_data = data[axis].values
        
        # Basic statistics
        features[f'{axis}_mean'] = np.mean(axis_data)
        features[f'{axis}_median'] = np.median(axis_data)
        features[f'{axis}_std'] = np.std(axis_data)
        features[f'{axis}_var'] = np.var(axis_data)
        features[f'{axis}_min'] = np.min(axis_data)
        features[f'{axis}_max'] = np.max(axis_data)
        features[f'{axis}_range'] = np.max(axis_data) - np.min(axis_data)
        features[f'{axis}_rms'] = np.sqrt(np.mean(np.square(axis_data)))
        
        # Distribution shape
        features[f'{axis}_skewness'] = stats.skew(axis_data)
        features[f'{axis}_kurtosis'] = stats.kurtosis(axis_data)
        features[f'{axis}_peak_to_peak'] = np.max(axis_data) - np.min(axis_data)
        
        # Energy
        features[f'{axis}_energy'] = np.sum(np.square(axis_data)) / len(axis_data)
        
        # Zero crossing rate
        zero_crossings = np.where(np.diff(np.signbit(axis_data)))[0]
        features[f'{axis}_zero_crossing_rate'] = len(zero_crossings) / len(axis_data)
    
    # Signal Magnitude Area (SMA)
    sma = np.mean(np.abs(data['x_norm']) + np.abs(data['y_norm']) + np.abs(data['z_norm']))
    features['sma'] = sma
    
    return features

# Frequency-domain features
def extract_frequency_domain_features(data, sampling_rate=100):  # Assuming 100Hz, adjust if different
    features = {}
    
    for axis in ['x_norm', 'y_norm', 'z_norm']:
        axis_data = data[axis].values
        
        # Compute FFT
        n = len(axis_data)
        fft_values = fft(axis_data)
        fft_magnitude = np.abs(fft_values[:n//2])
        freqs = np.fft.fftfreq(n, 1/sampling_rate)[:n//2]
        
        # Dominant frequency
        if len(fft_magnitude) > 0:
            features[f'{axis}_dominant_freq'] = freqs[np.argmax(fft_magnitude)]
        else:
            features[f'{axis}_dominant_freq'] = 0
            
        # Spectral energy
        features[f'{axis}_spectral_energy'] = np.sum(np.square(fft_magnitude)) / n
        
        # Spectral entropy
        if np.sum(fft_magnitude) > 0:
            prob = fft_magnitude / np.sum(fft_magnitude)
            # Add small value to avoid log(0)
            spectral_entropy = -np.sum(prob * np.log2(prob + 1e-10))
            features[f'{axis}_spectral_entropy'] = spectral_entropy
        else:
            features[f'{axis}_spectral_entropy'] = 0
        
        # Spectral centroid
        if np.sum(fft_magnitude) > 0:
            features[f'{axis}_spectral_centroid'] = np.sum(freqs * fft_magnitude) / np.sum(fft_magnitude)
        else:
            features[f'{axis}_spectral_centroid'] = 0
        
        # Band power (example: 0-10 Hz)
        low_freq = 0
        high_freq = 10
        band_indices = np.where((freqs >= low_freq) & (freqs <= high_freq))[0]
        if len(band_indices) > 0:
            features[f'{axis}_band_power_0_10Hz'] = np.sum(np.square(fft_magnitude[band_indices])) / len(band_indices)
        else:
            features[f'{axis}_band_power_0_10Hz'] = 0
        
        # First k FFT coefficients (e.g., first 5)
        k = min(5, len(fft_magnitude))
        for i in range(k):
            if i < len(fft_magnitude):
                features[f'{axis}_fft_coef_{i}'] = fft_magnitude[i]
            else:
                features[f'{axis}_fft_coef_{i}'] = 0
                
    return features

# Magnitude-based features
def extract_magnitude_features(data):
    features = {}
    
    # Calculate magnitude
    magnitude = np.sqrt(np.square(data['x_norm']) + np.square(data['y_norm']) + np.square(data['z_norm']))
    
    # Statistics on magnitude
    features['magnitude_mean'] = np.mean(magnitude)
    features['magnitude_var'] = np.var(magnitude)
    features['magnitude_rms'] = np.sqrt(np.mean(np.square(magnitude)))
    features['magnitude_max'] = np.max(magnitude)
    features['magnitude_min'] = np.min(magnitude)
    features['magnitude_range'] = np.max(magnitude) - np.min(magnitude)
    
    return features

# Cross-axis features
def extract_cross_axis_features(data):
    features = {}
    
    # Correlation coefficients
    corr_xy = np.corrcoef(data['x_norm'], data['y_norm'])[0, 1]
    corr_xz = np.corrcoef(data['x_norm'], data['z_norm'])[0, 1]
    corr_yz = np.corrcoef(data['y_norm'], data['z_norm'])[0, 1]
    
    features['correlation_xy'] = corr_xy
    features['correlation_xz'] = corr_xz
    features['correlation_yz'] = corr_yz
    
    # Covariance between axes
    features['covariance_xy'] = np.cov(data['x_norm'], data['y_norm'])[0, 1]
    features['covariance_xz'] = np.cov(data['x_norm'], data['z_norm'])[0, 1]
    features['covariance_yz'] = np.cov(data['y_norm'], data['z_norm'])[0, 1]
    
    # Angles between acceleration vectors (relative angles)
    # Using dot product formula: cos(θ) = (a·b) / (|a|·|b|)
    # Taking mean vectors for simplicity
    x_mean = np.mean(data['x_norm'])
    y_mean = np.mean(data['y_norm'])
    z_mean = np.mean(data['z_norm'])
    
    # Create vectors
    vec1 = np.array([x_mean, y_mean, 0])
    vec2 = np.array([x_mean, 0, z_mean])
    vec3 = np.array([0, y_mean, z_mean])
    
    # Compute norms
    norm1 = np.linalg.norm(vec1)
    norm2 = np.linalg.norm(vec2)
    norm3 = np.linalg.norm(vec3)
    
    # Calculate angles
    if norm1 > 0 and norm2 > 0:
        dot_product = np.dot(vec1, vec2)
        cos_angle = dot_product / (norm1 * norm2)
        # Clip to handle floating point errors
        cos_angle = np.clip(cos_angle, -1.0, 1.0)
        features['angle_xy_xz'] = np.arccos(cos_angle) * 180 / np.pi
    else:
        features['angle_xy_xz'] = 0
        
    if norm1 > 0 and norm3 > 0:
        dot_product = np.dot(vec1, vec3)
        cos_angle = dot_product / (norm1 * norm3)
        cos_angle = np.clip(cos_angle, -1.0, 1.0)
        features['angle_xy_yz'] = np.arccos(cos_angle) * 180 / np.pi
    else:
        features['angle_xy_yz'] = 0
        
    if norm2 > 0 and norm3 > 0:
        dot_product = np.dot(vec2, vec3)
        cos_angle = dot_product / (norm2 * norm3)
        cos_angle = np.clip(cos_angle, -1.0, 1.0)
        features['angle_xz_yz'] = np.arccos(cos_angle) * 180 / np.pi
    else:
        features['angle_xz_yz'] = 0
    
    return features

# Windowed/Segmented features
def extract_windowed_features(data, window_size=100):
    features = {}
    
    # If data is smaller than window size, use whole data
    if len(data) < window_size:
        window_size = len(data)
        
    # Create windows
    num_windows = len(data) // window_size
    
    # Initialize counters
    total_peaks = 0
    total_troughs = 0
    window_slopes = []
    
    for i in range(num_windows):
        start_idx = i * window_size
        end_idx = (i + 1) * window_size
        
        window_data = data.iloc[start_idx:end_idx]
        
        # Calculate slope for each axis in this window
        for axis in ['x_norm', 'y_norm', 'z_norm']:
            axis_data = window_data[axis].values
            
            if len(axis_data) > 1:
                # Linear regression for slope
                x = np.arange(len(axis_data))
                slope, _, _, _, _ = stats.linregress(x, axis_data)
                window_slopes.append(slope)
            
            # Find peaks and troughs
            peaks, _ = find_peaks(axis_data)
            troughs, _ = find_peaks(-axis_data)
            
            total_peaks += len(peaks)
            total_troughs += len(troughs)
    
    # Average features across windows
    features['avg_window_slope'] = np.mean(window_slopes) if window_slopes else 0
    features['total_peaks'] = total_peaks
    features['total_troughs'] = total_troughs
    features['peaks_per_window'] = total_peaks / max(1, num_windows)
    features['troughs_per_window'] = total_troughs / max(1, num_windows)
    
    # Activity counts (accumulated counts over a threshold)
    threshold = 0.5  # Adjust as needed
    activity_counts = np.sum(np.abs(data['x_norm']) > threshold) + \
                      np.sum(np.abs(data['y_norm']) > threshold) + \
                      np.sum(np.abs(data['z_norm']) > threshold)
    features['activity_counts'] = activity_counts
    
    return features

# Advanced features
def extract_advanced_features(data):
    features = {}
    
    # Signal Vector Magnitude (SVM)
    svm = np.mean(np.sqrt(np.square(data['x_norm']) + 
                          np.square(data['y_norm']) + 
                          np.square(data['z_norm'])))
    features['svm'] = svm
    
    # Tilt angles (assuming z is vertical)
    # Convert to radians and then degrees
    x_mean = np.mean(data['x_norm'])
    y_mean = np.mean(data['y_norm'])
    z_mean = np.mean(data['z_norm'])
    
    # Calculate tilt angles
    if z_mean != 0:
        features['tilt_x'] = np.arctan(x_mean / z_mean) * 180 / np.pi
    else:
        features['tilt_x'] = 90 if x_mean > 0 else -90
        
    if z_mean != 0:
        features['tilt_y'] = np.arctan(y_mean / z_mean) * 180 / np.pi
    else:
        features['tilt_y'] = 90 if y_mean > 0 else -90
    
    # Jerk (rate of change of acceleration) - first derivative
    jerk_x = np.diff(data['x_norm'])
    jerk_y = np.diff(data['y_norm'])
    jerk_z = np.diff(data['z_norm'])
    
    if len(jerk_x) > 0:
        features['jerk_x_mean'] = np.mean(np.abs(jerk_x))
        features['jerk_y_mean'] = np.mean(np.abs(jerk_y))
        features['jerk_z_mean'] = np.mean(np.abs(jerk_z))
        features['jerk_magnitude'] = np.mean(np.sqrt(np.square(jerk_x) + 
                                                    np.square(jerk_y) + 
                                                    np.square(jerk_z)))
    else:
        features['jerk_x_mean'] = 0
        features['jerk_y_mean'] = 0
        features['jerk_z_mean'] = 0
        features['jerk_magnitude'] = 0
    
    # Area under curve (AUC) - trapezoidal integration
    features['auc_x'] = np.trapz(np.abs(data['x_norm']))
    features['auc_y'] = np.trapz(np.abs(data['y_norm']))
    features['auc_z'] = np.trapz(np.abs(data['z_norm']))
    
    # Sample entropy (measure of complexity) - approximation using std
    features['entropy_x'] = np.log(2 * np.pi * np.e * np.std(data['x_norm'])**2) / 2 if np.std(data['x_norm']) > 0 else 0
    features['entropy_y'] = np.log(2 * np.pi * np.e * np.std(data['y_norm'])**2) / 2 if np.std(data['y_norm']) > 0 else 0
    features['entropy_z'] = np.log(2 * np.pi * np.e * np.std(data['z_norm'])**2) / 2 if np.std(data['z_norm']) > 0 else 0
    
    # Auto-correlation at lag k (for periodicity detection)
    lag = 1  # Adjust as needed
    if len(data) > lag:
        features['autocorr_x'] = np.corrcoef(data['x_norm'][:-lag], data['x_norm'][lag:])[0, 1]
        features['autocorr_y'] = np.corrcoef(data['y_norm'][:-lag], data['y_norm'][lag:])[0, 1]
        features['autocorr_z'] = np.corrcoef(data['z_norm'][:-lag], data['z_norm'][lag:])[0, 1]
    else:
        features['autocorr_x'] = 0
        features['autocorr_y'] = 0
        features['autocorr_z'] = 0
    
    return features

# Function to extract all features
def extract_all_features(data_file):
    try:
        # Read data
        data = pd.read_csv(data_file)
        
        # Check if file has the required columns
        required_columns = ['x_norm', 'y_norm', 'z_norm']
        if not all(col in data.columns for col in required_columns):
            print(f"Skipping {data_file} - missing required columns")
            return None, None
            
        # Get filename without directory and extension
        file_basename = os.path.basename(data_file)
        
        # Extract all features
        features = {}
        
        # Add file information
        features['file_name'] = file_basename
        features['char_name'] = os.path.splitext(file_basename)[0]
        
        # Time domain features
        time_features = extract_time_domain_features(data)
        features.update(time_features)
        
        # Frequency domain features
        freq_features = extract_frequency_domain_features(data)
        features.update(freq_features)
        
        # Magnitude features
        mag_features = extract_magnitude_features(data)
        features.update(mag_features)
        
        # Cross-axis features
        cross_features = extract_cross_axis_features(data)
        features.update(cross_features)
        
        # Windowed features
        window_features = extract_windowed_features(data)
        features.update(window_features)
        
        # Advanced features
        adv_features = extract_advanced_features(data)
        features.update(adv_features)
        
        return features, file_basename
        
    except Exception as e:
        print(f"Error processing {data_file}: {e}")
        return None, None

# Main function to traverse directory and extract features
def process_all_files(input_dir, output_dir):
    print(f"Starting to process files from: {input_dir}")
    
    # Create output directory if it doesn't exist
    create_dir_if_not_exists(output_dir)
    
    # List to store all features
    all_features = []
    file_count = 0
    
    # Traverse through all files in input directory and subdirectories
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.endswith('.csv'):
                # Full path to file
                file_path = os.path.join(root, file)
                print(f"Processing: {file_path}")
                
                # Extract features
                features, file_basename = extract_all_features(file_path)
                
                if features is not None:
                    all_features.append(features)
                    file_count += 1
                    
                    # Also save individual feature file
                    char_name = os.path.splitext(file_basename)[0]
                    individual_output_path = os.path.join(output_dir, f"{char_name}_features.csv")
                    
                    # Save as individual file
                    pd.DataFrame([features]).to_csv(individual_output_path, index=False)
                    print(f"Saved individual features to: {individual_output_path}")
    
    print(f"Processed {file_count} files")
    
    # Save all features to a single file if any were extracted
    if all_features:
        all_features_df = pd.DataFrame(all_features)
        all_features_path = os.path.join(output_dir, "all_features.csv")
        all_features_df.to_csv(all_features_path, index=False)
        print(f"Saved combined features to: {all_features_path}")
    else:
        print("No features were extracted.")

# Main execution
if __name__ == "__main__":
    # Define input and output directories
    input_directory = "preprocessed_data"
    output_directory = "featureExtraction"
    
    # Process all files
    process_all_files(input_directory, output_directory)
    print("Feature extraction complete!")
# Out:
# Starting to process files from: preprocessed_data
# Processing: preprocessed_data\অ\অ_36606b04_Right Hand_20250423_120617_preprocessed.csv
# Saved individual features to: featureExtraction\অ_36606b04_Right Hand_20250423_120617_preprocessed_features.csv
# Processing: preprocessed_data\অ\অ_36606b04_Right Hand_20250423_120731_preprocessed.csv
# Saved individual features to: featureExtraction\অ_36606b04_Right Hand_20250423_120731_preprocessed_features.csv
# Processing: preprocessed_data\আ\আ_36606b04_Right Hand_20250423_120748_preprocessed.csv
# Saved individual features to: featureExtraction\আ_36606b04_Right Hand_20250423_120748_preprocessed_features.csv
# Processing: preprocessed_data\আ\আ_36606b04_Right Hand_20250423_120805_preprocessed.csv
# Saved individual features to: featureExtraction\আ_36606b04_Right Hand_20250423_120805_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_01083526_Right Hand_20250423_122648_preprocessed.csv
# Saved individual features to: featureExtraction\ক_01083526_Right Hand_20250423_122648_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_01083526_Right Hand_20250423_122659_preprocessed.csv
# Saved individual features to: featureExtraction\ক_01083526_Right Hand_20250423_122659_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_01083526_Right Hand_20250423_122711_preprocessed.csv
# Saved individual features to: featureExtraction\ক_01083526_Right Hand_20250423_122711_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_041c8727_Right Hand_20250425_143649_preprocessed.csv
# Saved individual features to: featureExtraction\ক_041c8727_Right Hand_20250425_143649_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_041c8727_Right Hand_20250425_143657_preprocessed.csv
# Saved individual features to: featureExtraction\ক_041c8727_Right Hand_20250425_143657_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_0e4e9ee0_Right Hand_20250426_005722_preprocessed.csv
# Saved individual features to: featureExtraction\ক_0e4e9ee0_Right Hand_20250426_005722_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_0e4e9ee0_Right Hand_20250426_005730_preprocessed.csv
# Saved individual features to: featureExtraction\ক_0e4e9ee0_Right Hand_20250426_005730_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_117fb6fc_Right Hand_20250423_122340_preprocessed.csv
# Saved individual features to: featureExtraction\ক_117fb6fc_Right Hand_20250423_122340_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_117fb6fc_Right Hand_20250423_122352_preprocessed.csv
# Saved individual features to: featureExtraction\ক_117fb6fc_Right Hand_20250423_122352_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_1703ad9a_Right Hand_20250425_144058_preprocessed.csv
# Saved individual features to: featureExtraction\ক_1703ad9a_Right Hand_20250425_144058_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_1703ad9a_Right Hand_20250425_144107_preprocessed.csv
# Saved individual features to: featureExtraction\ক_1703ad9a_Right Hand_20250425_144107_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_1703ad9a_Right Hand_20250425_144115_preprocessed.csv
# Saved individual features to: featureExtraction\ক_1703ad9a_Right Hand_20250425_144115_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_1923bd89_Right Hand_20250426_011500_preprocessed.csv
# Saved individual features to: featureExtraction\ক_1923bd89_Right Hand_20250426_011500_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_1923bd89_Right Hand_20250426_011507_preprocessed.csv
# Saved individual features to: featureExtraction\ক_1923bd89_Right Hand_20250426_011507_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_22487d84_Right Hand_20250426_011646_preprocessed.csv
# Saved individual features to: featureExtraction\ক_22487d84_Right Hand_20250426_011646_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_22487d84_Right Hand_20250426_011653_preprocessed.csv
# Saved individual features to: featureExtraction\ক_22487d84_Right Hand_20250426_011653_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_247eff5d_Right Hand_20250426_010050_preprocessed.csv
# Saved individual features to: featureExtraction\ক_247eff5d_Right Hand_20250426_010050_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_247eff5d_Right Hand_20250426_010057_preprocessed.csv
# Saved individual features to: featureExtraction\ক_247eff5d_Right Hand_20250426_010057_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_2ab448b4_Right Hand_20250426_005531_preprocessed.csv
# Saved individual features to: featureExtraction\ক_2ab448b4_Right Hand_20250426_005531_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_2ab448b4_Right Hand_20250426_005539_preprocessed.csv
# Saved individual features to: featureExtraction\ক_2ab448b4_Right Hand_20250426_005539_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_36606b04_Right Hand_20250423_120831_preprocessed.csv
# Saved individual features to: featureExtraction\ক_36606b04_Right Hand_20250423_120831_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_36606b04_Right Hand_20250423_120849_preprocessed.csv
# Saved individual features to: featureExtraction\ক_36606b04_Right Hand_20250423_120849_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_36bd5490_Right Hand_20250423_122018_preprocessed.csv
# Saved individual features to: featureExtraction\ক_36bd5490_Right Hand_20250423_122018_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_36bd5490_Right Hand_20250423_122033_preprocessed.csv
# Saved individual features to: featureExtraction\ক_36bd5490_Right Hand_20250423_122033_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_39d76399_Right Hand_20250426_013548_preprocessed.csv
# Saved individual features to: featureExtraction\ক_39d76399_Right Hand_20250426_013548_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_39d76399_Right Hand_20250426_013554_preprocessed.csv
# Saved individual features to: featureExtraction\ক_39d76399_Right Hand_20250426_013554_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_456a1550_Right Hand_20250425_143902_preprocessed.csv
# Saved individual features to: featureExtraction\ক_456a1550_Right Hand_20250425_143902_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_456a1550_Right Hand_20250425_143911_preprocessed.csv
# Saved individual features to: featureExtraction\ক_456a1550_Right Hand_20250425_143911_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_5a43b542_Right Hand_20250426_013047_preprocessed.csv
# Saved individual features to: featureExtraction\ক_5a43b542_Right Hand_20250426_013047_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_5a43b542_Right Hand_20250426_013054_preprocessed.csv
# Saved individual features to: featureExtraction\ক_5a43b542_Right Hand_20250426_013054_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_6003e474_Right Hand_20250426_013226_preprocessed.csv
# Saved individual features to: featureExtraction\ক_6003e474_Right Hand_20250426_013226_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_6003e474_Right Hand_20250426_013234_preprocessed.csv
# Saved individual features to: featureExtraction\ক_6003e474_Right Hand_20250426_013234_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_646a88f3_Right Hand_20250426_012019_preprocessed.csv
# Saved individual features to: featureExtraction\ক_646a88f3_Right Hand_20250426_012019_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_646a88f3_Right Hand_20250426_012026_preprocessed.csv
# Saved individual features to: featureExtraction\ক_646a88f3_Right Hand_20250426_012026_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_6db67b35_Right Hand_20250426_013816_preprocessed.csv
# Saved individual features to: featureExtraction\ক_6db67b35_Right Hand_20250426_013816_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_6db67b35_Right Hand_20250426_013828_preprocessed.csv
# Saved individual features to: featureExtraction\ক_6db67b35_Right Hand_20250426_013828_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_75267423_Right Hand_20250426_011837_preprocessed.csv
# Saved individual features to: featureExtraction\ক_75267423_Right Hand_20250426_011837_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_75267423_Right Hand_20250426_011844_preprocessed.csv
# Saved individual features to: featureExtraction\ক_75267423_Right Hand_20250426_011844_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_8c67050d_Right Hand_20250425_143223_preprocessed.csv
# Saved individual features to: featureExtraction\ক_8c67050d_Right Hand_20250425_143223_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_8c67050d_Right Hand_20250425_143233_preprocessed.csv
# Saved individual features to: featureExtraction\ক_8c67050d_Right Hand_20250425_143233_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_93d87c4a_Right Hand_20250425_143436_preprocessed.csv
# Saved individual features to: featureExtraction\ক_93d87c4a_Right Hand_20250425_143436_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_93d87c4a_Right Hand_20250425_143444_preprocessed.csv
# Saved individual features to: featureExtraction\ক_93d87c4a_Right Hand_20250425_143444_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_95d236ec_Right Hand_20250423_123211_preprocessed.csv
# Saved individual features to: featureExtraction\ক_95d236ec_Right Hand_20250423_123211_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_95d236ec_Right Hand_20250423_123222_preprocessed.csv
# Saved individual features to: featureExtraction\ক_95d236ec_Right Hand_20250423_123222_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_978dd94d_Right Hand_20250426_013405_preprocessed.csv
# Saved individual features to: featureExtraction\ক_978dd94d_Right Hand_20250426_013405_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_978dd94d_Right Hand_20250426_013413_preprocessed.csv
# Saved individual features to: featureExtraction\ক_978dd94d_Right Hand_20250426_013413_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_9aec8fea_Right Hand_20250426_005908_preprocessed.csv
# Saved individual features to: featureExtraction\ক_9aec8fea_Right Hand_20250426_005908_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_9aec8fea_Right Hand_20250426_005916_preprocessed.csv
# Saved individual features to: featureExtraction\ক_9aec8fea_Right Hand_20250426_005916_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_b16dc8e1_Right Hand_20250423_121342_preprocessed.csv
# Saved individual features to: featureExtraction\ক_b16dc8e1_Right Hand_20250423_121342_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_b16dc8e1_Right Hand_20250423_121354_preprocessed.csv
# Saved individual features to: featureExtraction\ক_b16dc8e1_Right Hand_20250423_121354_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_e8020442_Right Hand_20250426_005347_preprocessed.csv
# Saved individual features to: featureExtraction\ক_e8020442_Right Hand_20250426_005347_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_e8020442_Right Hand_20250426_005356_preprocessed.csv
# Saved individual features to: featureExtraction\ক_e8020442_Right Hand_20250426_005356_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_f10a33d9_Right Hand_20250423_122941_preprocessed.csv
# Saved individual features to: featureExtraction\ক_f10a33d9_Right Hand_20250423_122941_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_f10a33d9_Right Hand_20250423_122953_preprocessed.csv
# Saved individual features to: featureExtraction\ক_f10a33d9_Right Hand_20250423_122953_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_f2a15d79_Right Hand_20250426_011146_preprocessed.csv
# Saved individual features to: featureExtraction\ক_f2a15d79_Right Hand_20250426_011146_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_f2a15d79_Right Hand_20250426_011320_preprocessed.csv
# Saved individual features to: featureExtraction\ক_f2a15d79_Right Hand_20250426_011320_preprocessed_features.csv
# Processing: preprocessed_data\ক\ক_f2a15d79_Right Hand_20250426_011328_preprocessed.csv
# Saved individual features to: featureExtraction\ক_f2a15d79_Right Hand_20250426_011328_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_01083526_Right Hand_20250423_122739_preprocessed.csv
# Saved individual features to: featureExtraction\খ_01083526_Right Hand_20250423_122739_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_01083526_Right Hand_20250423_122752_preprocessed.csv
# Saved individual features to: featureExtraction\খ_01083526_Right Hand_20250423_122752_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_041c8727_Right Hand_20250425_143712_preprocessed.csv
# Saved individual features to: featureExtraction\খ_041c8727_Right Hand_20250425_143712_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_041c8727_Right Hand_20250425_143721_preprocessed.csv
# Saved individual features to: featureExtraction\খ_041c8727_Right Hand_20250425_143721_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_0e4e9ee0_Right Hand_20250426_005741_preprocessed.csv
# Saved individual features to: featureExtraction\খ_0e4e9ee0_Right Hand_20250426_005741_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_0e4e9ee0_Right Hand_20250426_005748_preprocessed.csv
# Saved individual features to: featureExtraction\খ_0e4e9ee0_Right Hand_20250426_005748_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_117fb6fc_Right Hand_20250423_122409_preprocessed.csv
# Saved individual features to: featureExtraction\খ_117fb6fc_Right Hand_20250423_122409_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_117fb6fc_Right Hand_20250423_122435_preprocessed.csv
# Saved individual features to: featureExtraction\খ_117fb6fc_Right Hand_20250423_122435_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_1703ad9a_Right Hand_20250425_144128_preprocessed.csv
# Saved individual features to: featureExtraction\খ_1703ad9a_Right Hand_20250425_144128_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_1703ad9a_Right Hand_20250425_144137_preprocessed.csv
# Saved individual features to: featureExtraction\খ_1703ad9a_Right Hand_20250425_144137_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_1923bd89_Right Hand_20250426_011519_preprocessed.csv
# Saved individual features to: featureExtraction\খ_1923bd89_Right Hand_20250426_011519_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_1923bd89_Right Hand_20250426_011527_preprocessed.csv
# Saved individual features to: featureExtraction\খ_1923bd89_Right Hand_20250426_011527_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_22487d84_Right Hand_20250426_011707_preprocessed.csv
# Saved individual features to: featureExtraction\খ_22487d84_Right Hand_20250426_011707_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_22487d84_Right Hand_20250426_011714_preprocessed.csv
# Saved individual features to: featureExtraction\খ_22487d84_Right Hand_20250426_011714_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_247eff5d_Right Hand_20250426_010108_preprocessed.csv
# Saved individual features to: featureExtraction\খ_247eff5d_Right Hand_20250426_010108_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_247eff5d_Right Hand_20250426_010115_preprocessed.csv
# Saved individual features to: featureExtraction\খ_247eff5d_Right Hand_20250426_010115_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_2ab448b4_Right Hand_20250426_005549_preprocessed.csv
# Saved individual features to: featureExtraction\খ_2ab448b4_Right Hand_20250426_005549_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_2ab448b4_Right Hand_20250426_005557_preprocessed.csv
# Saved individual features to: featureExtraction\খ_2ab448b4_Right Hand_20250426_005557_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_36606b04_Right Hand_20250423_120920_preprocessed.csv
# Saved individual features to: featureExtraction\খ_36606b04_Right Hand_20250423_120920_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_36606b04_Right Hand_20250423_120938_preprocessed.csv
# Saved individual features to: featureExtraction\খ_36606b04_Right Hand_20250423_120938_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_36bd5490_Right Hand_20250423_122053_preprocessed.csv
# Saved individual features to: featureExtraction\খ_36bd5490_Right Hand_20250423_122053_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_36bd5490_Right Hand_20250423_122106_preprocessed.csv
# Saved individual features to: featureExtraction\খ_36bd5490_Right Hand_20250423_122106_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_36bd5490_Right Hand_20250423_122142_preprocessed.csv
# Saved individual features to: featureExtraction\খ_36bd5490_Right Hand_20250423_122142_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_39d76399_Right Hand_20250426_013604_preprocessed.csv
# Saved individual features to: featureExtraction\খ_39d76399_Right Hand_20250426_013604_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_39d76399_Right Hand_20250426_013612_preprocessed.csv
# Saved individual features to: featureExtraction\খ_39d76399_Right Hand_20250426_013612_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_456a1550_Right Hand_20250425_143923_preprocessed.csv
# Saved individual features to: featureExtraction\খ_456a1550_Right Hand_20250425_143923_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_456a1550_Right Hand_20250425_143932_preprocessed.csv
# Saved individual features to: featureExtraction\খ_456a1550_Right Hand_20250425_143932_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_5a43b542_Right Hand_20250426_013105_preprocessed.csv
# Saved individual features to: featureExtraction\খ_5a43b542_Right Hand_20250426_013105_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_5a43b542_Right Hand_20250426_013113_preprocessed.csv
# Saved individual features to: featureExtraction\খ_5a43b542_Right Hand_20250426_013113_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_6003e474_Right Hand_20250426_013244_preprocessed.csv
# Saved individual features to: featureExtraction\খ_6003e474_Right Hand_20250426_013244_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_6003e474_Right Hand_20250426_013252_preprocessed.csv
# Saved individual features to: featureExtraction\খ_6003e474_Right Hand_20250426_013252_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_646a88f3_Right Hand_20250426_012037_preprocessed.csv
# Saved individual features to: featureExtraction\খ_646a88f3_Right Hand_20250426_012037_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_646a88f3_Right Hand_20250426_012043_preprocessed.csv
# Saved individual features to: featureExtraction\খ_646a88f3_Right Hand_20250426_012043_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_6db67b35_Right Hand_20250426_013845_preprocessed.csv
# Saved individual features to: featureExtraction\খ_6db67b35_Right Hand_20250426_013845_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_6db67b35_Right Hand_20250426_013859_preprocessed.csv
# Saved individual features to: featureExtraction\খ_6db67b35_Right Hand_20250426_013859_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_6db67b35_Right Hand_20250426_013912_preprocessed.csv
# Saved individual features to: featureExtraction\খ_6db67b35_Right Hand_20250426_013912_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_75267423_Right Hand_20250426_011854_preprocessed.csv
# Saved individual features to: featureExtraction\খ_75267423_Right Hand_20250426_011854_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_75267423_Right Hand_20250426_011902_preprocessed.csv
# Saved individual features to: featureExtraction\খ_75267423_Right Hand_20250426_011902_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_8c67050d_Right Hand_20250425_143245_preprocessed.csv
# Saved individual features to: featureExtraction\খ_8c67050d_Right Hand_20250425_143245_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_8c67050d_Right Hand_20250425_143258_preprocessed.csv
# Saved individual features to: featureExtraction\খ_8c67050d_Right Hand_20250425_143258_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_93d87c4a_Right Hand_20250425_143503_preprocessed.csv
# Saved individual features to: featureExtraction\খ_93d87c4a_Right Hand_20250425_143503_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_93d87c4a_Right Hand_20250425_143512_preprocessed.csv
# Saved individual features to: featureExtraction\খ_93d87c4a_Right Hand_20250425_143512_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_95d236ec_Right Hand_20250423_123238_preprocessed.csv
# Saved individual features to: featureExtraction\খ_95d236ec_Right Hand_20250423_123238_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_95d236ec_Right Hand_20250423_123249_preprocessed.csv
# Saved individual features to: featureExtraction\খ_95d236ec_Right Hand_20250423_123249_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_978dd94d_Right Hand_20250426_013422_preprocessed.csv
# Saved individual features to: featureExtraction\খ_978dd94d_Right Hand_20250426_013422_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_978dd94d_Right Hand_20250426_013430_preprocessed.csv
# Saved individual features to: featureExtraction\খ_978dd94d_Right Hand_20250426_013430_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_9aec8fea_Right Hand_20250426_005927_preprocessed.csv
# Saved individual features to: featureExtraction\খ_9aec8fea_Right Hand_20250426_005927_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_9aec8fea_Right Hand_20250426_005933_preprocessed.csv
# Saved individual features to: featureExtraction\খ_9aec8fea_Right Hand_20250426_005933_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_b16dc8e1_Right Hand_20250423_121413_preprocessed.csv
# Saved individual features to: featureExtraction\খ_b16dc8e1_Right Hand_20250423_121413_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_b16dc8e1_Right Hand_20250423_121427_preprocessed.csv
# Saved individual features to: featureExtraction\খ_b16dc8e1_Right Hand_20250423_121427_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_e8020442_Right Hand_20250426_005408_preprocessed.csv
# Saved individual features to: featureExtraction\খ_e8020442_Right Hand_20250426_005408_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_e8020442_Right Hand_20250426_005416_preprocessed.csv
# Saved individual features to: featureExtraction\খ_e8020442_Right Hand_20250426_005416_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_f10a33d9_Right Hand_20250423_123009_preprocessed.csv
# Saved individual features to: featureExtraction\খ_f10a33d9_Right Hand_20250423_123009_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_f10a33d9_Right Hand_20250423_123022_preprocessed.csv
# Saved individual features to: featureExtraction\খ_f10a33d9_Right Hand_20250423_123022_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_f2a15d79_Right Hand_20250426_011338_preprocessed.csv
# Saved individual features to: featureExtraction\খ_f2a15d79_Right Hand_20250426_011338_preprocessed_features.csv
# Processing: preprocessed_data\খ\খ_f2a15d79_Right Hand_20250426_011347_preprocessed.csv
# Saved individual features to: featureExtraction\খ_f2a15d79_Right Hand_20250426_011347_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_01083526_Right Hand_20250423_122811_preprocessed.csv
# Saved individual features to: featureExtraction\গ_01083526_Right Hand_20250423_122811_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_01083526_Right Hand_20250423_122821_preprocessed.csv
# Saved individual features to: featureExtraction\গ_01083526_Right Hand_20250423_122821_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_041c8727_Right Hand_20250425_143741_preprocessed.csv
# Saved individual features to: featureExtraction\গ_041c8727_Right Hand_20250425_143741_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_041c8727_Right Hand_20250425_143749_preprocessed.csv
# Saved individual features to: featureExtraction\গ_041c8727_Right Hand_20250425_143749_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_0e4e9ee0_Right Hand_20250426_005759_preprocessed.csv
# Saved individual features to: featureExtraction\গ_0e4e9ee0_Right Hand_20250426_005759_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_0e4e9ee0_Right Hand_20250426_005807_preprocessed.csv
# Saved individual features to: featureExtraction\গ_0e4e9ee0_Right Hand_20250426_005807_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_117fb6fc_Right Hand_20250423_122452_preprocessed.csv
# Saved individual features to: featureExtraction\গ_117fb6fc_Right Hand_20250423_122452_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_117fb6fc_Right Hand_20250423_122506_preprocessed.csv
# Saved individual features to: featureExtraction\গ_117fb6fc_Right Hand_20250423_122506_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_1703ad9a_Right Hand_20250425_144149_preprocessed.csv
# Saved individual features to: featureExtraction\গ_1703ad9a_Right Hand_20250425_144149_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_1703ad9a_Right Hand_20250425_144157_preprocessed.csv
# Saved individual features to: featureExtraction\গ_1703ad9a_Right Hand_20250425_144157_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_1923bd89_Right Hand_20250426_011538_preprocessed.csv
# Saved individual features to: featureExtraction\গ_1923bd89_Right Hand_20250426_011538_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_1923bd89_Right Hand_20250426_011546_preprocessed.csv
# Saved individual features to: featureExtraction\গ_1923bd89_Right Hand_20250426_011546_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_22487d84_Right Hand_20250426_011724_preprocessed.csv
# Saved individual features to: featureExtraction\গ_22487d84_Right Hand_20250426_011724_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_22487d84_Right Hand_20250426_011733_preprocessed.csv
# Saved individual features to: featureExtraction\গ_22487d84_Right Hand_20250426_011733_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_247eff5d_Right Hand_20250426_010125_preprocessed.csv
# Saved individual features to: featureExtraction\গ_247eff5d_Right Hand_20250426_010125_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_247eff5d_Right Hand_20250426_010133_preprocessed.csv
# Saved individual features to: featureExtraction\গ_247eff5d_Right Hand_20250426_010133_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_2ab448b4_Right Hand_20250426_005608_preprocessed.csv
# Saved individual features to: featureExtraction\গ_2ab448b4_Right Hand_20250426_005608_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_2ab448b4_Right Hand_20250426_005615_preprocessed.csv
# Saved individual features to: featureExtraction\গ_2ab448b4_Right Hand_20250426_005615_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_36606b04_Right Hand_20250423_121000_preprocessed.csv
# Saved individual features to: featureExtraction\গ_36606b04_Right Hand_20250423_121000_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_36606b04_Right Hand_20250423_121017_preprocessed.csv
# Saved individual features to: featureExtraction\গ_36606b04_Right Hand_20250423_121017_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_36606b04_Right Hand_20250423_121036_preprocessed.csv
# Saved individual features to: featureExtraction\গ_36606b04_Right Hand_20250423_121036_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_36606b04_Right Hand_20250423_121050_preprocessed.csv
# Saved individual features to: featureExtraction\গ_36606b04_Right Hand_20250423_121050_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_36bd5490_Right Hand_20250423_122200_preprocessed.csv
# Saved individual features to: featureExtraction\গ_36bd5490_Right Hand_20250423_122200_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_36bd5490_Right Hand_20250423_122213_preprocessed.csv
# Saved individual features to: featureExtraction\গ_36bd5490_Right Hand_20250423_122213_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_39d76399_Right Hand_20250426_013622_preprocessed.csv
# Saved individual features to: featureExtraction\গ_39d76399_Right Hand_20250426_013622_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_39d76399_Right Hand_20250426_013634_preprocessed.csv
# Saved individual features to: featureExtraction\গ_39d76399_Right Hand_20250426_013634_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_456a1550_Right Hand_20250425_143943_preprocessed.csv
# Saved individual features to: featureExtraction\গ_456a1550_Right Hand_20250425_143943_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_456a1550_Right Hand_20250425_143952_preprocessed.csv
# Saved individual features to: featureExtraction\গ_456a1550_Right Hand_20250425_143952_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_5a43b542_Right Hand_20250426_013124_preprocessed.csv
# Saved individual features to: featureExtraction\গ_5a43b542_Right Hand_20250426_013124_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_5a43b542_Right Hand_20250426_013131_preprocessed.csv
# Saved individual features to: featureExtraction\গ_5a43b542_Right Hand_20250426_013131_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_6003e474_Right Hand_20250426_013302_preprocessed.csv
# Saved individual features to: featureExtraction\গ_6003e474_Right Hand_20250426_013302_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_6003e474_Right Hand_20250426_013309_preprocessed.csv
# Saved individual features to: featureExtraction\গ_6003e474_Right Hand_20250426_013309_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_646a88f3_Right Hand_20250426_012057_preprocessed.csv
# Saved individual features to: featureExtraction\গ_646a88f3_Right Hand_20250426_012057_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_646a88f3_Right Hand_20250426_012105_preprocessed.csv
# Saved individual features to: featureExtraction\গ_646a88f3_Right Hand_20250426_012105_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_6db67b35_Right Hand_20250426_013931_preprocessed.csv
# Saved individual features to: featureExtraction\গ_6db67b35_Right Hand_20250426_013931_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_6db67b35_Right Hand_20250426_013945_preprocessed.csv
# Saved individual features to: featureExtraction\গ_6db67b35_Right Hand_20250426_013945_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_75267423_Right Hand_20250426_011912_preprocessed.csv
# Saved individual features to: featureExtraction\গ_75267423_Right Hand_20250426_011912_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_75267423_Right Hand_20250426_011919_preprocessed.csv
# Saved individual features to: featureExtraction\গ_75267423_Right Hand_20250426_011919_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_8c67050d_Right Hand_20250425_143311_preprocessed.csv
# Saved individual features to: featureExtraction\গ_8c67050d_Right Hand_20250425_143311_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_8c67050d_Right Hand_20250425_143322_preprocessed.csv
# Saved individual features to: featureExtraction\গ_8c67050d_Right Hand_20250425_143322_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_93d87c4a_Right Hand_20250425_143526_preprocessed.csv
# Saved individual features to: featureExtraction\গ_93d87c4a_Right Hand_20250425_143526_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_93d87c4a_Right Hand_20250425_143539_preprocessed.csv
# Saved individual features to: featureExtraction\গ_93d87c4a_Right Hand_20250425_143539_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_95d236ec_Right Hand_20250423_123305_preprocessed.csv
# Saved individual features to: featureExtraction\গ_95d236ec_Right Hand_20250423_123305_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_95d236ec_Right Hand_20250423_123317_preprocessed.csv
# Saved individual features to: featureExtraction\গ_95d236ec_Right Hand_20250423_123317_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_978dd94d_Right Hand_20250426_013445_preprocessed.csv
# Saved individual features to: featureExtraction\গ_978dd94d_Right Hand_20250426_013445_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_978dd94d_Right Hand_20250426_013452_preprocessed.csv
# Saved individual features to: featureExtraction\গ_978dd94d_Right Hand_20250426_013452_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_9aec8fea_Right Hand_20250426_005946_preprocessed.csv
# Saved individual features to: featureExtraction\গ_9aec8fea_Right Hand_20250426_005946_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_9aec8fea_Right Hand_20250426_005953_preprocessed.csv
# Saved individual features to: featureExtraction\গ_9aec8fea_Right Hand_20250426_005953_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_b16dc8e1_Right Hand_20250423_121447_preprocessed.csv
# Saved individual features to: featureExtraction\গ_b16dc8e1_Right Hand_20250423_121447_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_b16dc8e1_Right Hand_20250423_121501_preprocessed.csv
# Saved individual features to: featureExtraction\গ_b16dc8e1_Right Hand_20250423_121501_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_e8020442_Right Hand_20250426_005427_preprocessed.csv
# Saved individual features to: featureExtraction\গ_e8020442_Right Hand_20250426_005427_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_e8020442_Right Hand_20250426_005435_preprocessed.csv
# Saved individual features to: featureExtraction\গ_e8020442_Right Hand_20250426_005435_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_f10a33d9_Right Hand_20250423_123038_preprocessed.csv
# Saved individual features to: featureExtraction\গ_f10a33d9_Right Hand_20250423_123038_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_f10a33d9_Right Hand_20250423_123050_preprocessed.csv
# Saved individual features to: featureExtraction\গ_f10a33d9_Right Hand_20250423_123050_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_f2a15d79_Right Hand_20250426_011359_preprocessed.csv
# Saved individual features to: featureExtraction\গ_f2a15d79_Right Hand_20250426_011359_preprocessed_features.csv
# Processing: preprocessed_data\গ\গ_f2a15d79_Right Hand_20250426_011406_preprocessed.csv
# Saved individual features to: featureExtraction\গ_f2a15d79_Right Hand_20250426_011406_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_01083526_Right Hand_20250423_122836_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_01083526_Right Hand_20250423_122836_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_01083526_Right Hand_20250423_122848_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_01083526_Right Hand_20250423_122848_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_041c8727_Right Hand_20250425_143801_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_041c8727_Right Hand_20250425_143801_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_041c8727_Right Hand_20250425_143809_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_041c8727_Right Hand_20250425_143809_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_0e4e9ee0_Right Hand_20250426_005817_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_0e4e9ee0_Right Hand_20250426_005817_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_0e4e9ee0_Right Hand_20250426_005825_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_0e4e9ee0_Right Hand_20250426_005825_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_117fb6fc_Right Hand_20250423_122528_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_117fb6fc_Right Hand_20250423_122528_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_117fb6fc_Right Hand_20250423_122540_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_117fb6fc_Right Hand_20250423_122540_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_1703ad9a_Right Hand_20250425_144209_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_1703ad9a_Right Hand_20250425_144209_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_1703ad9a_Right Hand_20250425_144220_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_1703ad9a_Right Hand_20250425_144220_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_1923bd89_Right Hand_20250426_011557_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_1923bd89_Right Hand_20250426_011557_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_1923bd89_Right Hand_20250426_011605_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_1923bd89_Right Hand_20250426_011605_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_22487d84_Right Hand_20250426_011744_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_22487d84_Right Hand_20250426_011744_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_22487d84_Right Hand_20250426_011751_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_22487d84_Right Hand_20250426_011751_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_247eff5d_Right Hand_20250426_010145_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_247eff5d_Right Hand_20250426_010145_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_247eff5d_Right Hand_20250426_010245_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_247eff5d_Right Hand_20250426_010245_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_2ab448b4_Right Hand_20250426_005625_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_2ab448b4_Right Hand_20250426_005625_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_2ab448b4_Right Hand_20250426_005640_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_2ab448b4_Right Hand_20250426_005640_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_36606b04_Right Hand_20250423_121111_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_36606b04_Right Hand_20250423_121111_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_36606b04_Right Hand_20250423_121127_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_36606b04_Right Hand_20250423_121127_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_36606b04_Right Hand_20250423_121143_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_36606b04_Right Hand_20250423_121143_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_36bd5490_Right Hand_20250423_122226_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_36bd5490_Right Hand_20250423_122226_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_36bd5490_Right Hand_20250423_122241_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_36bd5490_Right Hand_20250423_122241_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_39d76399_Right Hand_20250426_013710_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_39d76399_Right Hand_20250426_013710_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_39d76399_Right Hand_20250426_013721_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_39d76399_Right Hand_20250426_013721_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_456a1550_Right Hand_20250425_144003_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_456a1550_Right Hand_20250425_144003_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_456a1550_Right Hand_20250425_144012_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_456a1550_Right Hand_20250425_144012_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_5a43b542_Right Hand_20250426_013141_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_5a43b542_Right Hand_20250426_013141_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_5a43b542_Right Hand_20250426_013148_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_5a43b542_Right Hand_20250426_013148_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_6003e474_Right Hand_20250426_013319_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_6003e474_Right Hand_20250426_013319_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_6003e474_Right Hand_20250426_013327_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_6003e474_Right Hand_20250426_013327_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_646a88f3_Right Hand_20250426_012116_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_646a88f3_Right Hand_20250426_012116_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_646a88f3_Right Hand_20250426_012123_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_646a88f3_Right Hand_20250426_012123_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_6db67b35_Right Hand_20250426_014004_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_6db67b35_Right Hand_20250426_014004_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_6db67b35_Right Hand_20250426_014015_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_6db67b35_Right Hand_20250426_014015_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_75267423_Right Hand_20250426_011930_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_75267423_Right Hand_20250426_011930_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_75267423_Right Hand_20250426_011937_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_75267423_Right Hand_20250426_011937_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_8c67050d_Right Hand_20250425_143335_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_8c67050d_Right Hand_20250425_143335_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_8c67050d_Right Hand_20250425_143344_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_8c67050d_Right Hand_20250425_143344_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_93d87c4a_Right Hand_20250425_143552_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_93d87c4a_Right Hand_20250425_143552_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_93d87c4a_Right Hand_20250425_143600_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_93d87c4a_Right Hand_20250425_143600_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_95d236ec_Right Hand_20250423_123332_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_95d236ec_Right Hand_20250423_123332_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_95d236ec_Right Hand_20250423_123344_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_95d236ec_Right Hand_20250423_123344_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_95d236ec_Right Hand_20250423_123356_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_95d236ec_Right Hand_20250423_123356_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_978dd94d_Right Hand_20250426_013503_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_978dd94d_Right Hand_20250426_013503_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_978dd94d_Right Hand_20250426_013510_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_978dd94d_Right Hand_20250426_013510_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_9aec8fea_Right Hand_20250426_010004_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_9aec8fea_Right Hand_20250426_010004_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_9aec8fea_Right Hand_20250426_010011_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_9aec8fea_Right Hand_20250426_010011_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_b16dc8e1_Right Hand_20250423_121522_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_b16dc8e1_Right Hand_20250423_121522_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_b16dc8e1_Right Hand_20250423_121535_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_b16dc8e1_Right Hand_20250423_121535_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_e8020442_Right Hand_20250426_005446_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_e8020442_Right Hand_20250426_005446_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_e8020442_Right Hand_20250426_005453_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_e8020442_Right Hand_20250426_005453_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_f10a33d9_Right Hand_20250423_123105_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_f10a33d9_Right Hand_20250423_123105_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_f10a33d9_Right Hand_20250423_123116_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_f10a33d9_Right Hand_20250423_123116_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_f2a15d79_Right Hand_20250426_011416_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_f2a15d79_Right Hand_20250426_011416_preprocessed_features.csv
# Processing: preprocessed_data\ঘ\ঘ_f2a15d79_Right Hand_20250426_011424_preprocessed.csv
# Saved individual features to: featureExtraction\ঘ_f2a15d79_Right Hand_20250426_011424_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_01083526_Right Hand_20250423_122905_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_01083526_Right Hand_20250423_122905_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_01083526_Right Hand_20250423_122919_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_01083526_Right Hand_20250423_122919_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_041c8727_Right Hand_20250425_143821_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_041c8727_Right Hand_20250425_143821_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_041c8727_Right Hand_20250425_143834_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_041c8727_Right Hand_20250425_143834_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_0e4e9ee0_Right Hand_20250426_005835_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_0e4e9ee0_Right Hand_20250426_005835_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_0e4e9ee0_Right Hand_20250426_005843_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_0e4e9ee0_Right Hand_20250426_005843_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_117fb6fc_Right Hand_20250423_122559_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_117fb6fc_Right Hand_20250423_122559_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_117fb6fc_Right Hand_20250423_122610_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_117fb6fc_Right Hand_20250423_122610_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_1703ad9a_Right Hand_20250425_144231_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_1703ad9a_Right Hand_20250425_144231_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_1703ad9a_Right Hand_20250425_144245_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_1703ad9a_Right Hand_20250425_144245_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_1923bd89_Right Hand_20250426_011617_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_1923bd89_Right Hand_20250426_011617_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_1923bd89_Right Hand_20250426_011624_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_1923bd89_Right Hand_20250426_011624_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_22487d84_Right Hand_20250426_011802_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_22487d84_Right Hand_20250426_011802_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_22487d84_Right Hand_20250426_011809_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_22487d84_Right Hand_20250426_011809_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_247eff5d_Right Hand_20250426_010255_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_247eff5d_Right Hand_20250426_010255_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_247eff5d_Right Hand_20250426_010302_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_247eff5d_Right Hand_20250426_010302_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_2ab448b4_Right Hand_20250426_005650_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_2ab448b4_Right Hand_20250426_005650_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_2ab448b4_Right Hand_20250426_005658_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_2ab448b4_Right Hand_20250426_005658_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_36606b04_Right Hand_20250423_121205_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_36606b04_Right Hand_20250423_121205_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_36606b04_Right Hand_20250423_121222_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_36606b04_Right Hand_20250423_121222_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_36bd5490_Right Hand_20250423_122256_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_36bd5490_Right Hand_20250423_122256_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_36bd5490_Right Hand_20250423_122309_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_36bd5490_Right Hand_20250423_122309_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_39d76399_Right Hand_20250426_013735_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_39d76399_Right Hand_20250426_013735_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_39d76399_Right Hand_20250426_013746_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_39d76399_Right Hand_20250426_013746_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_456a1550_Right Hand_20250425_144023_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_456a1550_Right Hand_20250425_144023_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_456a1550_Right Hand_20250425_144031_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_456a1550_Right Hand_20250425_144031_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_5a43b542_Right Hand_20250426_013158_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_5a43b542_Right Hand_20250426_013158_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_5a43b542_Right Hand_20250426_013205_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_5a43b542_Right Hand_20250426_013205_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_6003e474_Right Hand_20250426_013336_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_6003e474_Right Hand_20250426_013336_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_6003e474_Right Hand_20250426_013344_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_6003e474_Right Hand_20250426_013344_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_646a88f3_Right Hand_20250426_012135_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_646a88f3_Right Hand_20250426_012135_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_646a88f3_Right Hand_20250426_012142_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_646a88f3_Right Hand_20250426_012142_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_6db67b35_Right Hand_20250426_014029_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_6db67b35_Right Hand_20250426_014029_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_6db67b35_Right Hand_20250426_014039_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_6db67b35_Right Hand_20250426_014039_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_75267423_Right Hand_20250426_011946_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_75267423_Right Hand_20250426_011946_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_75267423_Right Hand_20250426_011955_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_75267423_Right Hand_20250426_011955_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_8c67050d_Right Hand_20250425_143404_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_8c67050d_Right Hand_20250425_143404_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_8c67050d_Right Hand_20250425_143413_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_8c67050d_Right Hand_20250425_143413_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_93d87c4a_Right Hand_20250425_143614_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_93d87c4a_Right Hand_20250425_143614_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_93d87c4a_Right Hand_20250425_143621_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_93d87c4a_Right Hand_20250425_143621_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_95d236ec_Right Hand_20250423_123417_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_95d236ec_Right Hand_20250423_123417_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_95d236ec_Right Hand_20250423_123428_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_95d236ec_Right Hand_20250423_123428_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_978dd94d_Right Hand_20250426_013522_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_978dd94d_Right Hand_20250426_013522_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_978dd94d_Right Hand_20250426_013529_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_978dd94d_Right Hand_20250426_013529_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_9aec8fea_Right Hand_20250426_010022_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_9aec8fea_Right Hand_20250426_010022_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_9aec8fea_Right Hand_20250426_010032_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_9aec8fea_Right Hand_20250426_010032_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_b16dc8e1_Right Hand_20250423_121551_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_b16dc8e1_Right Hand_20250423_121551_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_b16dc8e1_Right Hand_20250423_121605_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_b16dc8e1_Right Hand_20250423_121605_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_e8020442_Right Hand_20250426_005504_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_e8020442_Right Hand_20250426_005504_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_e8020442_Right Hand_20250426_005511_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_e8020442_Right Hand_20250426_005511_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_f10a33d9_Right Hand_20250423_123132_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_f10a33d9_Right Hand_20250423_123132_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_f10a33d9_Right Hand_20250423_123142_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_f10a33d9_Right Hand_20250423_123142_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_f2a15d79_Right Hand_20250426_011434_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_f2a15d79_Right Hand_20250426_011434_preprocessed_features.csv
# Processing: preprocessed_data\ঙ\ঙ_f2a15d79_Right Hand_20250426_011441_preprocessed.csv
# Saved individual features to: featureExtraction\ঙ_f2a15d79_Right Hand_20250426_011441_preprocessed_features.csv
# Processed 283 files
# Saved combined features to: featureExtraction\all_features.csv
# Feature extraction complete!
